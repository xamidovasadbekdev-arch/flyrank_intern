# %% [markdown]
# <a href="https://colab.research.google.com/github/xamidovasadbekdev-arch/flyrank_intern/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/xamidovasadbekdev-arch/flyrank_intern/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

"""I'm choosing **Lane 2: Refresh / Content Opportunity Scoring**.

Working through the starter notebook, I found several signals that point
this direction: declining pages ("down" trend_direction) were actually
younger on average (236 days) than stable or growing pages (295 and 288
days) — the opposite of what I expected. I also found that word count
doesn't explain decline (down vs up pages have nearly identical median
word counts), so the cause of decline isn't simply "old, thin content."
This makes me want to dig into what actually predicts decline, and build
a system to help prioritize which declining pages are worth reviewing
first — rather than just flagging every page that dropped."""
# Out:
# 'I\'m choosing **Lane 2: Refresh / Content Opportunity Scoring**.\n\nWorking through the starter notebook, I found several signals that point \nthis direction: declining pages ("down" trend_direction) were actually \nyounger on average (236 days) than stable or growing pages (295 and 288 \ndays) — the opposite of what I expected. I also found that word count \ndoesn\'t explain decline (down vs up pages have nearly identical median \nword counts), so the cause of decline isn\'t simply "old, thin content." \nThis makes me want to dig into what actually predicts decline, and build \na system to help prioritize which declining pages are worth reviewing \nfirst — rather than just flagging every page that dropped.'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

"""
**Decision:** Which declining pages should a content editor review and refresh
first, given limited time to review every page?

**Who acts, and how:** A content/SEO editor uses the ranked list to prioritize
their week — reviewing and rewriting the highest-priority pages rather than
working through pages randomly.

**Cost of a wrong call:**
- If we flag a page as high-priority but it wasn't really declining, the editor
  wastes hours reviewing a page that didn't need it.
- If we miss a real decline, that page keeps losing visibility and traffic
  unnoticed until it's much worse.

**Why ML/data helps instead of a simple rule:** A simple rule like "flag anything
old" doesn't work — I already found that declining pages are actually younger
on average (236 days) than stable pages (295 days), and word count doesn't
separate declining from growing pages either. The real pattern is tangled
across several signals at once, which is exactly where a learned model can
help more than a single if-statement.

"""
# Out:
# '\n**Decision:** Which declining pages should a content editor review and refresh \nfirst, given limited time to review every page?\n\n**Who acts, and how:** A content/SEO editor uses the ranked list to prioritize \ntheir week — reviewing and rewriting the highest-priority pages rather than \nworking through pages randomly.\n\n**Cost of a wrong call:** \n- If we flag a page as high-priority but it wasn\'t really declining, the editor \n  wastes hours reviewing a page that didn\'t need it.\n- If we miss a real decline, that page keeps losing visibility and traffic \n  unnoticed until it\'s much worse.\n\n**Why ML/data helps instead of a simple rule:** A simple rule like "flag anything \nold" doesn\'t work — I already found that declining pages are actually younger \non average (236 days) than stable pages (295 days), and word count doesn\'t \nseparate declining from growing pages either. The real pattern is tangled \nacross several signals at once, which is exactly where a learned mod
# ...

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, subprocess

REPO_URL = "https://github.com/xamidovasadbekdev-arch/flyrank_intern"
REPO_DIR = "flyrank_intern"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)
print("Now in:", os.getcwd())
print(os.listdir())
# Out:
# Now in: /content/flyrank_intern/flyrank_intern
# ['scripts', 'AGENTS.md', 'requirements.txt', 'data', '.gitignore', 'README.md', 'submission', 'CLAUDE.md', '.github', 'work', 'LICENSE', 'DATA_USE.md', 'notebooks', 'skills', 'outputs', 'docs', 'SETUP.md', '.git', 'GUIDE.md']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

decline_pct = (df["trend_direction"] == "down").mean() * 100
print(f"1) {decline_pct:.1f}% of pages are currently declining ({(df['trend_direction']=='down').sum()} of {len(df)})")

age_by_trend = df.groupby("trend_direction")["content_age_days"].mean()
print(f"\n2) Avg content age by trend direction:\n{age_by_trend.round(1)}")

wc_by_trend = df.groupby("trend_direction")["word_count"].median()
print(f"\n3) Median word count by trend direction:\n{wc_by_trend}")
# Out:
# 1) 54.2% of pages are currently declining (16262 of 30000)
#
# 2) Avg content age by trend direction:
# trend_direction
# down      236.2
# flat      245.9
# new       238.7
# stable    295.4
# up        288.5
# Name: content_age_days, dtype: float64
#
# 3) Median word count by trend direction:
# trend_direction
# down      2909.0
# flat      2698.5
# new       2239.0
# stable    2912.5
# up        2847.5
# Name: word_count, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""
## Careful Words: What I Can and Can't Claim

**What I can claim:** My analysis observes patterns in this dataset — for example,
that decline is common (54.2% of pages) and that simple explanations like age or
word count don't fully explain it. Any scoring system I build is decision-support:
it helps a human reviewer prioritize their time, not a guarantee that a flagged
page will actually recover if refreshed.

**What I cannot claim:** I cannot say this data proves what Google's ranking
algorithm does. I cannot say a page will definitely improve if refreshed — that
would require an actual experiment (like refreshing some pages and comparing to
similar pages left alone), not just this observational data. My findings are
observed and directional, not causal.
"""
# Out:
# "\n## Careful Words: What I Can and Can't Claim\n\n**What I can claim:** My analysis observes patterns in this dataset — for example, \nthat decline is common (54.2% of pages) and that simple explanations like age or \nword count don't fully explain it. Any scoring system I build is decision-support: \nit helps a human reviewer prioritize their time, not a guarantee that a flagged \npage will actually recover if refreshed.\n\n**What I cannot claim:** I cannot say this data proves what Google's ranking \nalgorithm does. I cannot say a page will definitely improve if refreshed — that \nwould require an actual experiment (like refreshing some pages and comparing to \nsimilar pages left alone), not just this observational data. My findings are \nobserved and directional, not causal.\n"

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
